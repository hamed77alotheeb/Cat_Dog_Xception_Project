# %%
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score
)

# =========================================================
# 1) إعداد المسارات
# =========================================================

DATASET_PATH = os.path.join(os.getcwd(), "dataset")
TEST_PATH = os.path.join(os.getcwd(), "test")

IMG_SIZE = (224, 224)
BATCH_SIZE = 16
SEED = 1337

print("Dataset:", DATASET_PATH)
print("Test:", TEST_PATH)

# =========================================================
# 2) تحميل بيانات التدريب + Validation
#    80% تدريب / 20% Validation
# =========================================================

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.20,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.20,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False
)

print("\nClasses:", train_ds.class_names)

# =========================================================
# 3) تحميل Test بشكل مستقل
# =========================================================

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_PATH,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False
)

print("Test classes:", test_ds.class_names)

# التأكد من ترتيب الفئات
assert train_ds.class_names == test_ds.class_names, \
    "ترتيب فئات train و test غير متطابق!"

# =========================================================
# 4) تحسين سرعة قراءة البيانات
# =========================================================

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(
    1000,
    seed=SEED
).prefetch(AUTOTUNE)

val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

# =========================================================
# 5) Data Augmentation
# =========================================================

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.10),
    layers.RandomTranslation(
        height_factor=0.05,
        width_factor=0.05
    ),
], name="data_augmentation")

# =========================================================
# 6) بناء Xception
# =========================================================

base_model = Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

# المرحلة الأولى:
# تجميد Xception بالكامل
base_model.trainable = False

inputs = layers.Input(
    shape=(224, 224, 3),
    name="input_image"
)

x = data_augmentation(inputs)

# Preprocessing خاص بـ Xception
x = tf.keras.applications.xception.preprocess_input(x)

x = base_model(
    x,
    training=False
)

x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)

x = layers.Dropout(0.35)(x)

outputs = layers.Dense(
    1,
    activation="sigmoid",
    name="prediction"
)(x)

model = models.Model(
    inputs,
    outputs,
    name="Cat_Dog_Xception"
)

model.summary()

# =========================================================
# 7) المرحلة الأولى
#    تدريب الرأس فقط
# =========================================================

print("\n" + "=" * 60)
print("المرحلة الأولى: Transfer Learning")
print("=" * 60)

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=1e-3
    ),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

checkpoint_stage1 = ModelCheckpoint(
    "best_stage1.weights.h5",
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

early_stop_stage1 = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_stage1 = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=[
        checkpoint_stage1,
        early_stop_stage1,
        reduce_lr_stage1
    ]
)

# تحميل أفضل أوزان من المرحلة الأولى
model.load_weights("best_stage1.weights.h5")

# =========================================================
# 8) المرحلة الثانية:
#    Fine-Tuning
# =========================================================

print("\n" + "=" * 60)
print("المرحلة الثانية: Fine-Tuning")
print("=" * 60)

# فتح النموذج الأساسي
base_model.trainable = True

# تجميد أغلب الطبقات
# وفتح آخر 40 طبقة فقط
for layer in base_model.layers[:-40]:
    layer.trainable = False

# إبقاء BatchNormalization مجمدة
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

# إعادة Compile بمعدل تعلم صغير جدًا
model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=1e-5
    ),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

checkpoint_stage2 = ModelCheckpoint(
    "best_cat_dog_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early_stop_stage2 = EarlyStopping(
    monitor="val_loss",
    patience=7,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_stage2 = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-8,
    verbose=1
)

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[
        checkpoint_stage2,
        early_stop_stage2,
        reduce_lr_stage2
    ]
)

# =========================================================
# 9) تحميل أفضل نموذج
# =========================================================

print("\nتحميل أفضل نموذج...")

model = tf.keras.models.load_model(
    "best_cat_dog_model.keras"
)

# =========================================================
# 10) تقييم Validation
# =========================================================

print("\n" + "=" * 60)
print("نتيجة Validation")
print("=" * 60)

val_results = model.evaluate(
    val_ds,
    verbose=1
)

for name, value in zip(
    model.metrics_names,
    val_results
):
    print(f"{name}: {value:.4f}")

# =========================================================
# 11) تقييم Test الحقيقي
# =========================================================

print("\n" + "=" * 60)
print("نتيجة Test")
print("=" * 60)

test_results = model.evaluate(
    test_ds,
    verbose=1
)

for name, value in zip(
    model.metrics_names,
    test_results
):
    print(f"{name}: {value:.4f}")

# =========================================================
# 12) استخراج التوقعات
# =========================================================

y_true = []
y_pred_prob = []

for images, labels in test_ds:
    predictions = model.predict(
        images,
        verbose=0
    )

    y_true.extend(
        labels.numpy().astype(int).flatten()
    )

    y_pred_prob.extend(
        predictions.flatten()
    )

y_true = np.array(y_true)
y_pred_prob = np.array(y_pred_prob)

# Threshold = 0.5
y_pred = (y_pred_prob >= 0.5).astype(int)

# =========================================================
# 13) Accuracy
# =========================================================

test_accuracy = accuracy_score(
    y_true,
    y_pred
)

print("\nTest Accuracy:")
print(f"{test_accuracy * 100:.2f}%")

# =========================================================
# 14) Classification Report
# =========================================================

print("\n" + "=" * 60)
print("Classification Report")
print("=" * 60)

print(
    classification_report(
        y_true,
        y_pred,
        target_names=test_ds.class_names,
        digits=4
    )
)

# =========================================================
# 15) Confusion Matrix
# =========================================================

cm = confusion_matrix(
    y_true,
    y_pred
)

print("\n" + "=" * 60)
print("Confusion Matrix")
print("=" * 60)

print(cm)

# =========================================================
# 16) عرض أخطاء الاختبار
# =========================================================

print("\n" + "=" * 60)
print("ملخص الاختبار")
print("=" * 60)

correct = np.sum(y_true == y_pred)
wrong = np.sum(y_true != y_pred)

print(f"عدد صور الاختبار: {len(y_true)}")
print(f"التوقعات الصحيحة: {correct}")
print(f"التوقعات الخاطئة: {wrong}")
print(f"Accuracy: {correct / len(y_true) * 100:.2f}%")

# =========================================================
# 17) حفظ النموذج النهائي
# =========================================================

model.save(
    "ultimate_cat_dog_model.keras"
)

print("\n" + "=" * 60)
print("تم حفظ النموذج بنجاح")
print("ultimate_cat_dog_model.keras")
print("=" * 60)
# Out:
# Dataset: D:\Ai 3\ddd\Dr.1\Dr.1\dataset
# Test: D:\Ai 3\ddd\Dr.1\Dr.1\test
# Found 1852 files belonging to 2 classes.
# Using 1482 files for training.
# Found 1852 files belonging to 2 classes.
# Using 370 files for validation.
#
# Classes: ['cats', 'dogs']
# Found 54 files belonging to 2 classes.
# Test classes: ['cats', 'dogs']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 596s 7us/step
# Model: "Cat_Dog_Xception"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, 224, 224, 3)      0
#  al)
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization_4 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  prediction (Dense)          (None, 1)                 2049
#
# =================================================================
# Total params: 20,871,721
# Trainable params: 6,145
# Non-trainable params: 20,865,576
# _________________________________________________________________
#
# ============================================================
# المرحلة الأولى: Transfer Learning
# ============================================================
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
#
20
# 93/93 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9858 - precision: 0.9853 - recall: 0.9866
# Epoch 4: val_accuracy did not improve from 0.99459
# 93/93 [==============================] - 49s 527ms/step - loss: 0.0394 - accuracy: 0.9858 - precision: 0.9853 - recall: 0.9866 - val_loss: 0.0332 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 1.0000e-05
# Epoch 5/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9872 - precision: 0.9879 - recall: 0.9866
# Epoch 5: val_accuracy did not improve from 0.99459
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 93/93 [==============================] - 49s 525ms/step - loss: 0.0386 - accuracy: 0.9872 - precision: 0.9879 - recall: 0.9866 - val_loss: 0.0371 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 1.0000e-05
# Epoch 6/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9906 - precision: 0.9933 - recall: 0.9880
# Epoch 6: val_accuracy did not improve from 0.99459
# 93/93 [==============================] - 50s 533ms/step - loss: 0.0262 - accuracy: 0.9906 - precision: 0.9933 - recall: 0.9880 - val_loss: 0.0328 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 3.0000e-06
# Epoch 7/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9919 - precision: 0.9893 - recall: 0.9946
# Epoch 7: val_accuracy did not improve from 0.99459
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
# 93/93 [==============================] - 49s 533ms/step - loss: 0.0251 - accuracy: 0.9919 - precision: 0.9893 - recall: 0.9946 - val_loss: 0.0326 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 3.0000e-06
# Epoch 8/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9946 - precision: 0.9920 - recall: 0.9973
# Epoch 8: val_accuracy did not improve from 0.99459
# 93/93 [==============================] - 49s 528ms/step - loss: 0.0146 - accuracy: 0.9946 - precision: 0.9920 - recall: 0.9973 - val_loss: 0.0328 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 9.0000e-07
# Epoch 9/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9946 - precision: 0.9973 - recall: 0.9920
# Epoch 9: val_accuracy did not improve from 0.99459
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.6999999249710525e-07.
# 93/93 [==============================] - 47s 504ms/step - loss: 0.0197 - accuracy: 0.9946 - precision: 0.9973 - recall: 0.9920 - val_loss: 0.0314 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 9.0000e-07
# Epoch 10/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9953 - precision: 0.9947 - recall: 0.9960
# Epoch 10: val_accuracy did not improve from 0.99459
# Restoring model weights from the end of the best epoch: 3.
# 93/93 [==============================] - 48s 516ms/step - loss: 0.0177 - accuracy: 0.9953 - precision: 0.9947 - recall: 0.9960 - val_loss: 0.0316 - val_accuracy: 0.9946 - val_precision: 1.0000 - val_recall: 0.9946 - lr: 2.7000e-07
# Epoch 10: early stopping
#
# تحميل أفضل نموذج...
#
# ============================================================
# نتيجة Validation
# ============================================================
# 24/24 [==============================] - 5s 175ms/step - loss: 0.0328 - accuracy: 0.9946 - precision: 1.0000 - recall: 0.9946
# loss: 0.0328
# accuracy: 0.9946
# precision: 1.0000
# recall: 0.9946
#
# ============================================================
# نتيجة Test
# ============================================================
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0177 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# loss: 0.0177
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
#
# Test Accuracy:
# 100.00%
#
# ============================================================
# Classification Report
# ============================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 382
#     375 print("Classification Report")
#     376 print("=" * 60)
#     378 print(
#     379     classification_report(
#     380         y_true,
#     381         y_pred,
# --> 382         target_names=test_ds.class_names,
#     383         digits=4
#     384     )
#     385 )
#     387 # =========================================================
#     388 # 15) Confusion Matrix
#     389 # =========================================================
#     391 cm = confusion_matrix(
#     392     y_true,
#     393     y_pred
#     394 )
#
# AttributeError: 'PrefetchDataset' object has no attribute 'class_names'

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# أسماء الفئات محفوظة مسبقًا
class_names = ['cats', 'dogs']

# Classification Report
print("\n" + "=" * 60)
print("Classification Report")
print("=" * 60)

print(
    classification_report(
        y_true,
        y_pred,
        target_names=class_names,
        digits=4
    )
)

# Confusion Matrix
print("\n" + "=" * 60)
print("Confusion Matrix")
print("=" * 60)

cm = confusion_matrix(y_true, y_pred)
print(cm)

# ملخص الاختبار
print("\n" + "=" * 60)
print("ملخص الاختبار")
print("=" * 60)

correct = np.sum(y_true == y_pred)
wrong = np.sum(y_true != y_pred)

print(f"عدد صور الاختبار: {len(y_true)}")
print(f"التوقعات الصحيحة: {correct}")
print(f"التوقعات الخاطئة: {wrong}")
print(f"Accuracy: {correct / len(y_true) * 100:.2f}%")

# حفظ النموذج
model.save("ultimate_cat_dog_model.keras")

print("\nتم حفظ النموذج بنجاح:")
print("ultimate_cat_dog_model.keras")
# Out:
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#         cats     1.0000    1.0000    1.0000        27
#         dogs     1.0000    1.0000    1.0000        27
#
#     accuracy                         1.0000        54
#    macro avg     1.0000    1.0000    1.0000        54
# weighted avg     1.0000    1.0000    1.0000        54
#
#
# ============================================================
# Confusion Matrix
# ============================================================
# [[27  0]
#  [ 0 27]]
#
# ============================================================
# ملخص الاختبار
# ============================================================
# عدد صور الاختبار: 54
# التوقعات الصحيحة: 54
# التوقعات الخاطئة: 0
# Accuracy: 100.00%
#
# تم حفظ النموذج بنجاح:
# ultimate_cat_dog_model.keras

# %%
# =========================================================
# واجهة رفع صورة وتصنيفها إلى Cat / Dog
# =========================================================

import os
import numpy as np
import tensorflow as tf
import gradio as gr

# تحميل النموذج المحفوظ
MODEL_PATH = "ultimate_cat_dog_model.keras"

if not os.path.exists(MODEL_PATH):
    raise FileNotFoundError(
        f"لم يتم العثور على النموذج: {MODEL_PATH}"
    )

model = tf.keras.models.load_model(MODEL_PATH)

IMG_SIZE = (224, 224)

# ---------------------------------------------------------
# دالة التنبؤ
# ---------------------------------------------------------
def predict_image(image):
    if image is None:
        return "يرجى اختيار صورة أولاً."

    try:
        # تحويل الصورة إلى RGB
        image = image.convert("RGB")

        # تجهيز الصورة
        img = image.resize(IMG_SIZE)
        img_array = np.array(img, dtype=np.float32)

        # إضافة بعد Batch
        img_array = np.expand_dims(img_array, axis=0)

        # Preprocessing الخاص بـ Xception
        img_array = tf.keras.applications.xception.preprocess_input(
            img_array
        )

        # التنبؤ
        probability = float(
            model.predict(img_array, verbose=0)[0][0]
        )

        # probability >= 0.5 = Dog
        if probability >= 0.5:
            result = "🐶 DOG"
            confidence = probability * 100
        else:
            result = "🐱 CAT"
            confidence = (1 - probability) * 100

        return f"{result}\nنسبة الثقة: {confidence:.2f}%"

    except Exception as e:
        return f"حدث خطأ:\n{e}"


# ---------------------------------------------------------
# إنشاء الواجهة
# ---------------------------------------------------------
interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(
        type="pil",
        label="📷 ارفع صورة قط أو كلب"
    ),
    outputs=gr.Textbox(
        label="🔍 النتيجة",
        lines=3
    ),
    title="🐱🐶 Cat vs Dog Classifier",
    description="ارفع صورة وسيتعرف النموذج هل هي قطة أم كلب.",
    allow_flagging="never"
)

# تشغيل الواجهة
interface.launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 8
#       6 import numpy as np
#       7 import tensorflow as tf
# ----> 8 import gradio as gr
#      10 # تحميل النموذج المحفوظ
#      11 MODEL_PATH = "ultimate_cat_dog_model.keras"
#
# ModuleNotFoundError: No module named 'gradio'

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.44.1-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (4.12.1)
# Collecting fastapi<1.0 (from gradio)
#   Downloading fastapi-0.128.8-py3-none-any.whl.metadata (30 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.3.0 (from gradio)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (3.9.4)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.5-cp39-cp39-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: packaging in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (2.3.3)
# Collecting pillow<11.0,>=8.0 (from gradio)
#   Downloading pillow-10.4.0-cp39-cp39-win_amd64.whl.metadata (9.3 kB)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.13.5-py3-none-any.whl.metadata (110 kB)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (6.0.3)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.16.7-py3-none-win_amd64.whl.metadata (21 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.23.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from gradio) (2.5.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.39.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting fsspec (from gradio-client==1.3.0->gradio)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio)
#   Downloading websockets-12.0-cp39-cp39-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Collecting starlette<1.0.0,>=0.40.0 (from fastapi<1.0->gradio)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0->gradio)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0->gradio)
#   Using cached annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2026.3)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=12.3.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: certifi in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from httpx>=0.24.1->gradio) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.19.3->gradio)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub>=0.19.3->gradio)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.19.3->gradio)
#   Using cached tqdm-4.70.1-py3-none-any.whl.metadata (57 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.5 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.46.5-cp39-cp39-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\elite\anaconda3\envs\ai_hameed\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-4.44.1-py3-none-any.whl (18.1 MB)
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.5/18.1 MB 114.1 kB/s eta 0:02:34
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
#    - -------------------------------------- 0.8/18.1 MB 125.2 kB/s eta 0:02:19
kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, websockets, typing-inspection, tqdm, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, pillow, orjson, markupsafe, hf-xet, fsspec, filelock, ffmpy, click, annotated-types, annotated-doc, aiofiles, uvicorn, pydantic, typer, starlette, huggingface-hub, fastapi, gradio-client, gradio
#
#    - --------------------------------------  1/29 [websockets]
#    ---- -----------------------------------  3/29 [tqdm]
#    -------- -------------------------------  6/29 [semantic-version]
#    --------- ------------------------------  7/29 [ruff]
#   Attempting uninstall: pillow
#    --------- ------------------------------  7/29 [ruff]
#     Found existing installation: pillow 11.3.0
#    --------- ------------------------------  7/29 [ruff]
#    ------------- -------------------------- 10/29 [pillow]
#     Uninstalling pillow-11.3.0:
#    ------------- -------------------------- 10/29 [pillow]
#       Successfully uninstalled pillow-11.3.0
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#    ------------- -------------------------- 10/29 [pillow]
#   Attempting uninstall: markupsafe
#    ------------- -------------------------- 10/29 [pillow]
#     Found existing installation: MarkupSafe 3.0.2
#    ------------- -------------------------- 10/29 [pillow]
#     Uninstalling MarkupSafe-3.0.2:
#    ------------- -------------------------- 10/29 [pillow]
#       Successfully uninstalled MarkupSafe-3.0.2
#    ------------- -------------------------- 10/29 [pillow]
#    ------------------- -------------------- 14/29 [fsspec]
#    ------------------- -------------------- 14/29 [fsspec]
#    ----------------------- ---------------- 17/29 [click]
#    --------------------------- ------------ 20/29 [aiofiles]
#    ---------------------------- ----------- 21/29 [uvicorn]
#    ------------------------------ --------- 22/29 [pydantic]
#    ------------------------------ --------- 22/29 [pydantic]
#    ------------------------------ --------- 22/29 [pydantic]
#    --------------------------------- ------ 24/29 [starlette]
#    ---------------------------------- ----- 25/29 [huggingface-hub]
#    ---------------------------------- ----- 25/29 [huggingface-hub]
#    ---------------------------------- ----- 25/29 [huggingface-hub]
#    ---------------------------------- ----- 25/29 [huggingface-hub]
#    ---------------------------------- ----- 25/29 [huggingface-hub]
#    ----------------------------------- ---- 26/29 [fastapi]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    -------------------------------------- - 28/29 [gradio]
#    ---------------------------------------- 29/29 [gradio]
#
# Successfully installed aiofiles-23.2.1 annotated-doc-0.0.5 annotated-types-0.7.0 click-8.1.8 fastapi-0.128.8 ffmpy-1.0.0 filelock-3.19.1 fsspec-2025.10.0 gradio-4.44.1 gradio-client-1.3.0 hf-xet-1.6.0 huggingface-hub-1.8.0 markupsafe-2.1.5 orjson-3.11.5 pillow-10.4.0 pydantic-2.13.5 pydantic-core-2.46.5 pydub-0.25.1 python-multipart-0.0.20 ruff-0.16.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.49.3 tomlkit-0.12.0 tqdm-4.70.1 typer-0.23.2 typing-inspection-0.4.2 uvicorn-0.39.0 websockets-12.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Elite\anaconda3\envs\Ai_hameed\Lib\site-packages\~il'.
#   You can safely remove it manually.

# %%
import sys
import subprocess

subprocess.check_call([
    sys.executable,
    "-m",
    "pip",
    "install",
    "gradio"
])

print("✅ تم تثبيت Gradio بنجاح")
# Out:
# ✅ تم تثبيت Gradio بنجاح

# %%
# =========================================================
# واجهة رفع صورة وتصنيفها إلى Cat / Dog
# =========================================================

import os
import numpy as np
import tensorflow as tf
import gradio as gr

# تحميل النموذج المحفوظ
MODEL_PATH = "ultimate_cat_dog_model.keras"

if not os.path.exists(MODEL_PATH):
    raise FileNotFoundError(
        f"لم يتم العثور على النموذج: {MODEL_PATH}"
    )

model = tf.keras.models.load_model(MODEL_PATH)

IMG_SIZE = (224, 224)

# ---------------------------------------------------------
# دالة التنبؤ
# ---------------------------------------------------------
def predict_image(image):
    if image is None:
        return "يرجى اختيار صورة أولاً."

    try:
        # تحويل الصورة إلى RGB
        image = image.convert("RGB")

        # تجهيز الصورة
        img = image.resize(IMG_SIZE)
        img_array = np.array(img, dtype=np.float32)

        # إضافة بعد Batch
        img_array = np.expand_dims(img_array, axis=0)

        # Preprocessing الخاص بـ Xception
        img_array = tf.keras.applications.xception.preprocess_input(
            img_array
        )

        # التنبؤ
        probability = float(
            model.predict(img_array, verbose=0)[0][0]
        )

        # probability >= 0.5 = Dog
        if probability >= 0.5:
            result = "🐶 DOG"
            confidence = probability * 100
        else:
            result = "🐱 CAT"
            confidence = (1 - probability) * 100

        return f"{result}\nنسبة الثقة: {confidence:.2f}%"

    except Exception as e:
        return f"حدث خطأ:\n{e}"


# ---------------------------------------------------------
# إنشاء الواجهة
# ---------------------------------------------------------
interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(
        type="pil",
        label="📷 ارفع صورة قط أو كلب"
    ),
    outputs=gr.Textbox(
        label="🔍 النتيجة",
        lines=3
    ),
    title="🐱🐶 Cat vs Dog Classifier",
    description="ارفع صورة وسيتعرف النموذج هل هي قطة أم كلب.",
    allow_flagging="never"
)

# تشغيل الواجهة
interface.launch()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 8
#       6 import numpy as np
#       7 import tensorflow as tf
# ----> 8 import gradio as gr
#      10 # تحميل النموذج المحفوظ
#      11 MODEL_PATH = "ultimate_cat_dog_model.keras"
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\__init__.py:3
#       1 import json
# ----> 3 import gradio._simple_templates
#       4 import gradio.image_utils
#       5 import gradio.processing_utils
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\__init__.py:1
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpleimage import SimpleImage
#       3 from .simpletextbox import SimpleTextbox
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\simpledropdown.py:6
#       3 import warnings
#       4 from typing import TYPE_CHECKING, Any, Callable, Sequence
# ----> 6 from gradio.components.base import Component, FormComponent
#       7 from gradio.events import Events
#       9 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\__init__.py:1
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.base import (
#       4     Component,
#       5     FormComponent,
#    (...)
#      10     get_component_instance,
#      11 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\annotated_image.py:14
#      11 from gradio_client.documentation import document
#      13 from gradio import processing_utils, utils
# ---> 14 from gradio.components.base import Component
#      15 from gradio.data_classes import FileData, GradioModel
#      16 from gradio.events import Events
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\base.py:20
#      17 import gradio_client.utils as client_utils
#      19 from gradio import utils
# ---> 20 from gradio.blocks import Block, BlockContext
#      21 from gradio.component_meta import ComponentMeta
#      22 from gradio.data_classes import BaseModel, DeveloperPath, GradioDataModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\blocks.py:39
#      36 from gradio_client import utils as client_utils
#      37 from gradio_client.documentation import document
# ---> 39 from gradio import (
#      40     analytics,
#      41     components,
#      42     networking,
#      43     processing_utils,
#      44     queueing,
#      45     routes,
#      46     strings,
#      47     themes,
#      48     utils,
#      49     wasm_utils,
#      50 )
#      51 from gradio.blocks_events import BlocksEvents, BlocksMeta
#      52 from gradio.context import (
#      53     Context,
#      54     LocalContext,
#    (...)
#      57     set_render_context,
#      58 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\networking.py:15
#      11 import warnings
#      13 import httpx
# ---> 15 from gradio.routes import App  # HACK: to avoid circular import # noqa: F401
#      16 from gradio.tunneling import Tunnel
#      18 GRADIO_API_SERVER = "https://api.gradio.app/v2/tunnel-request"
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\routes.py:69
#      66 from starlette.responses import RedirectResponse, StreamingResponse
#      68 import gradio
# ---> 69 from gradio import ranged_response, route_utils, utils, wasm_utils
#      70 from gradio.context import Context
#      71 from gradio.data_classes import (
#      72     CancelBody,
#      73     ComponentServerBlobBody,
#    (...)
#      81     UserProvidedPath,
#      82 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\route_utils.py:53
#      47 from gradio.data_classes import (
#      48     BlocksConfigDict,
#      49     PredictBody,
#      50     PredictBodyInternal,
#      51 )
#      52 from gradio.exceptions import Error
# ---> 53 from gradio.helpers import EventData
#      54 from gradio.state_holder import SessionState
#      56 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\helpers.py:26
#      23 from gradio_client import utils as client_utils
#      24 from gradio_client.documentation import document
# ---> 26 from gradio import components, oauth, processing_utils, routes, utils, wasm_utils
#      27 from gradio.context import Context, LocalContext, get_blocks_context
#      28 from gradio.data_classes import GradioModel, GradioRootModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\oauth.py:13
#      11 import fastapi
#      12 from fastapi.responses import RedirectResponse
# ---> 13 from huggingface_hub import HfFolder, whoami
#      15 from .utils import get_space
#      17 OAUTH_CLIENT_ID = os.environ.get("OAUTH_CLIENT_ID")
#
# ImportError: cannot import name 'HfFolder' from 'huggingface_hub' (C:\Users\Elite\anaconda3\envs\Ai_hameed\lib\site-packages\huggingface_hub\__init__.py)

# %%
import os
import numpy as np
import tensorflow as tf
import gradio as gr

MODEL_PATH = "ultimate_cat_dog_model.keras"

model = tf.keras.models.load_model(MODEL_PATH)

IMG_SIZE = (224, 224)

def predict_image(image):
    if image is None:
        return "يرجى اختيار صورة أولاً."

    image = image.convert("RGB")
    img = image.resize(IMG_SIZE)
    img_array = np.array(img, dtype=np.float32)
    img_array = np.expand_dims(img_array, axis=0)

    img_array = tf.keras.applications.xception.preprocess_input(
        img_array
    )

    probability = float(
        model.predict(img_array, verbose=0)[0][0]
    )

    if probability >= 0.5:
        result = "🐶 DOG"
        confidence = probability * 100
    else:
        result = "🐱 CAT"
        confidence = (1 - probability) * 100

    return f"{result}\nنسبة الثقة: {confidence:.2f}%"

interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(
        type="pil",
        label="📷 ارفع صورة قط أو كلب"
    ),
    outputs=gr.Textbox(
        label="🔍 النتيجة",
        lines=3
    ),
    title="🐱🐶 Cat vs Dog Classifier",
    description="ارفع صورة قط أو كلب وسيقوم النموذج بتصنيفها."
)

interface.launch()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 4
#       2 import numpy as np
#       3 import tensorflow as tf
# ----> 4 import gradio as gr
#       6 MODEL_PATH = "ultimate_cat_dog_model.keras"
#       8 model = tf.keras.models.load_model(MODEL_PATH)
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\__init__.py:3
#       1 import json
# ----> 3 import gradio._simple_templates
#       4 import gradio.image_utils
#       5 import gradio.processing_utils
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\__init__.py:1
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpleimage import SimpleImage
#       3 from .simpletextbox import SimpleTextbox
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\simpledropdown.py:6
#       3 import warnings
#       4 from typing import TYPE_CHECKING, Any, Callable, Sequence
# ----> 6 from gradio.components.base import Component, FormComponent
#       7 from gradio.events import Events
#       9 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\__init__.py:1
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.base import (
#       4     Component,
#       5     FormComponent,
#    (...)
#      10     get_component_instance,
#      11 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\annotated_image.py:14
#      11 from gradio_client.documentation import document
#      13 from gradio import processing_utils, utils
# ---> 14 from gradio.components.base import Component
#      15 from gradio.data_classes import FileData, GradioModel
#      16 from gradio.events import Events
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\base.py:20
#      17 import gradio_client.utils as client_utils
#      19 from gradio import utils
# ---> 20 from gradio.blocks import Block, BlockContext
#      21 from gradio.component_meta import ComponentMeta
#      22 from gradio.data_classes import BaseModel, DeveloperPath, GradioDataModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\blocks.py:39
#      36 from gradio_client import utils as client_utils
#      37 from gradio_client.documentation import document
# ---> 39 from gradio import (
#      40     analytics,
#      41     components,
#      42     networking,
#      43     processing_utils,
#      44     queueing,
#      45     routes,
#      46     strings,
#      47     themes,
#      48     utils,
#      49     wasm_utils,
#      50 )
#      51 from gradio.blocks_events import BlocksEvents, BlocksMeta
#      52 from gradio.context import (
#      53     Context,
#      54     LocalContext,
#    (...)
#      57     set_render_context,
#      58 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\networking.py:15
#      11 import warnings
#      13 import httpx
# ---> 15 from gradio.routes import App  # HACK: to avoid circular import # noqa: F401
#      16 from gradio.tunneling import Tunnel
#      18 GRADIO_API_SERVER = "https://api.gradio.app/v2/tunnel-request"
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\routes.py:69
#      66 from starlette.responses import RedirectResponse, StreamingResponse
#      68 import gradio
# ---> 69 from gradio import ranged_response, route_utils, utils, wasm_utils
#      70 from gradio.context import Context
#      71 from gradio.data_classes import (
#      72     CancelBody,
#      73     ComponentServerBlobBody,
#    (...)
#      81     UserProvidedPath,
#      82 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\route_utils.py:53
#      47 from gradio.data_classes import (
#      48     BlocksConfigDict,
#      49     PredictBody,
#      50     PredictBodyInternal,
#      51 )
#      52 from gradio.exceptions import Error
# ---> 53 from gradio.helpers import EventData
#      54 from gradio.state_holder import SessionState
#      56 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\helpers.py:26
#      23 from gradio_client import utils as client_utils
#      24 from gradio_client.documentation import document
# ---> 26 from gradio import components, oauth, processing_utils, routes, utils, wasm_utils
#      27 from gradio.context import Context, LocalContext, get_blocks_context
#      28 from gradio.data_classes import GradioModel, GradioRootModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\oauth.py:13
#      11 import fastapi
#      12 from fastapi.responses import RedirectResponse
# ---> 13 from huggingface_hub import HfFolder, whoami
#      15 from .utils import get_space
#      17 OAUTH_CLIENT_ID = os.environ.get("OAUTH_CLIENT_ID")
#
# ImportError: cannot import name 'HfFolder' from 'huggingface_hub' (C:\Users\Elite\anaconda3\envs\Ai_hameed\lib\site-packages\huggingface_hub\__init__.py)

# %%
import gradio as gr
print("Gradio يعمل:", gr.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import gradio as gr
#       2 print("Gradio يعمل:", gr.__version__)
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\__init__.py:3
#       1 import json
# ----> 3 import gradio._simple_templates
#       4 import gradio.image_utils
#       5 import gradio.processing_utils
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\__init__.py:1
# ----> 1 from .simpledropdown import SimpleDropdown
#       2 from .simpleimage import SimpleImage
#       3 from .simpletextbox import SimpleTextbox
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\_simple_templates\simpledropdown.py:6
#       3 import warnings
#       4 from typing import TYPE_CHECKING, Any, Callable, Sequence
# ----> 6 from gradio.components.base import Component, FormComponent
#       7 from gradio.events import Events
#       9 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\__init__.py:1
# ----> 1 from gradio.components.annotated_image import AnnotatedImage
#       2 from gradio.components.audio import Audio
#       3 from gradio.components.base import (
#       4     Component,
#       5     FormComponent,
#    (...)
#      10     get_component_instance,
#      11 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\annotated_image.py:14
#      11 from gradio_client.documentation import document
#      13 from gradio import processing_utils, utils
# ---> 14 from gradio.components.base import Component
#      15 from gradio.data_classes import FileData, GradioModel
#      16 from gradio.events import Events
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\components\base.py:20
#      17 import gradio_client.utils as client_utils
#      19 from gradio import utils
# ---> 20 from gradio.blocks import Block, BlockContext
#      21 from gradio.component_meta import ComponentMeta
#      22 from gradio.data_classes import BaseModel, DeveloperPath, GradioDataModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\blocks.py:39
#      36 from gradio_client import utils as client_utils
#      37 from gradio_client.documentation import document
# ---> 39 from gradio import (
#      40     analytics,
#      41     components,
#      42     networking,
#      43     processing_utils,
#      44     queueing,
#      45     routes,
#      46     strings,
#      47     themes,
#      48     utils,
#      49     wasm_utils,
#      50 )
#      51 from gradio.blocks_events import BlocksEvents, BlocksMeta
#      52 from gradio.context import (
#      53     Context,
#      54     LocalContext,
#    (...)
#      57     set_render_context,
#      58 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\networking.py:15
#      11 import warnings
#      13 import httpx
# ---> 15 from gradio.routes import App  # HACK: to avoid circular import # noqa: F401
#      16 from gradio.tunneling import Tunnel
#      18 GRADIO_API_SERVER = "https://api.gradio.app/v2/tunnel-request"
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\routes.py:69
#      66 from starlette.responses import RedirectResponse, StreamingResponse
#      68 import gradio
# ---> 69 from gradio import ranged_response, route_utils, utils, wasm_utils
#      70 from gradio.context import Context
#      71 from gradio.data_classes import (
#      72     CancelBody,
#      73     ComponentServerBlobBody,
#    (...)
#      81     UserProvidedPath,
#      82 )
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\route_utils.py:53
#      47 from gradio.data_classes import (
#      48     BlocksConfigDict,
#      49     PredictBody,
#      50     PredictBodyInternal,
#      51 )
#      52 from gradio.exceptions import Error
# ---> 53 from gradio.helpers import EventData
#      54 from gradio.state_holder import SessionState
#      56 if TYPE_CHECKING:
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\helpers.py:26
#      23 from gradio_client import utils as client_utils
#      24 from gradio_client.documentation import document
# ---> 26 from gradio import components, oauth, processing_utils, routes, utils, wasm_utils
#      27 from gradio.context import Context, LocalContext, get_blocks_context
#      28 from gradio.data_classes import GradioModel, GradioRootModel
#
# File ~\anaconda3\envs\Ai_hameed\lib\site-packages\gradio\oauth.py:13
#      11 import fastapi
#      12 from fastapi.responses import RedirectResponse
# ---> 13 from huggingface_hub import HfFolder, whoami
#      15 from .utils import get_space
#      17 OAUTH_CLIENT_ID = os.environ.get("OAUTH_CLIENT_ID")
#
# ImportError: cannot import name 'HfFolder' from 'huggingface_hub' (C:\Users\Elite\anaconda3\envs\Ai_hameed\lib\site-packages\huggingface_hub\__init__.py)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Elite\anaconda3\envs\Ai_hameed\python.exe

# %%
import sys
import subprocess

print("Python المستخدم:")
print(sys.executable)

subprocess.check_call([
    sys.executable,
    "-m", "pip", "install",
    "--force-reinstall",
    "huggingface_hub==0.25.2"
])

print("✅ انتهى تثبيت huggingface_hub")
# Out:
# Python المستخدم:
# C:\Users\Elite\anaconda3\envs\Ai_hameed\python.exe
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[20], line 7
#       4 print("Python المستخدم:")
#       5 print(sys.executable)
# ----> 7 subprocess.check_call([
#       8     sys.executable,
#       9     "-m", "pip", "install",
#      10     "--force-reinstall",
#      11     "huggingface_hub==0.25.2"
#      12 ])
#      14 print("✅ انتهى تثبيت huggingface_hub")
#
# File ~\anaconda3\envs\Ai_hameed\lib\subprocess.py:373, in check_call(*popenargs, **kwargs)
#     371     if cmd is None:
#     372         cmd = popenargs[0]
# --> 373     raise CalledProcessError(retcode, cmd)
#     374 return 0
#
# CalledProcessError: Command '['C:\\Users\\Elite\\anaconda3\\envs\\Ai_hameed\\python.exe', '-m', 'pip', 'install', '--force-reinstall', 'huggingface_hub==0.25.2']' returned non-zero exit status 1.

# %%
import huggingface_hub
print("huggingface_hub:", huggingface_hub.__version__)

# %%
import gradio as gr
print("Gradio:", gr.__version__)
# Out:
# Gradio: 3.50.2

# %%
import numpy as np
import tensorflow as tf
import gradio as gr

MODEL_PATH = "ultimate_cat_dog_model.keras"
IMG_SIZE = (224, 224)

model = tf.keras.models.load_model(MODEL_PATH)

def predict_image(image):
    if image is None:
        return "يرجى اختيار صورة أولاً."

    image = image.convert("RGB")
    image = image.resize(IMG_SIZE)

    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    x = tf.keras.applications.xception.preprocess_input(x)

    p = float(model.predict(x, verbose=0)[0][0])

    if p >= 0.5:
        label = "🐶 DOG"
        confidence = p * 100
    else:
        label = "🐱 CAT"
        confidence = (1 - p) * 100

    return f"{label}\nنسبة الثقة: {confidence:.2f}%"

demo = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil", label="📷 ارفع صورة قط أو كلب"),
    outputs=gr.Textbox(label="🔍 النتيجة"),
    title="🐱🐶 Cat vs Dog Classifier",
    description="ارفع صورة وسيقوم النموذج بتحديد هل هي قطة أم كلب."
)

demo.launch()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image

MODEL_PATH = "ultimate_cat_dog_model.keras"
TEST_PATH = "test"
IMG_SIZE = (224, 224)

model = tf.keras.models.load_model(MODEL_PATH)

def predict_file(path):
    image = Image.open(path).convert("RGB")
    image = image.resize(IMG_SIZE)

    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    x = tf.keras.applications.xception.preprocess_input(x)

    p_dog = float(model.predict(x, verbose=0)[0][0])
    p_cat = 1.0 - p_dog

    return p_cat, p_dog


correct_cats = 0
correct_dogs = 0
total_cats = 0
total_dogs = 0

for filename in os.listdir(os.path.join(TEST_PATH, "cats")):
    path = os.path.join(TEST_PATH, "cats", filename)

    try:
        p_cat, p_dog = predict_file(path)
        total_cats += 1

        if p_cat >= p_dog:
            correct_cats += 1
        else:
            print("❌ قطة تم تصنيفها كلب:", filename)
    except:
        pass


for filename in os.listdir(os.path.join(TEST_PATH, "dogs")):
    path = os.path.join(TEST_PATH, "dogs", filename)

    try:
        p_cat, p_dog = predict_file(path)
        total_dogs += 1

        if p_dog >= p_cat:
            correct_dogs += 1
        else:
            print("❌ كلب تم تصنيفه قطة:", filename)
    except:
        pass


print("=" * 50)
print("نتيجة الاختبار بنفس طريقة الواجهة")
print("=" * 50)

print(f"Cats: {correct_cats}/{total_cats}")
print(f"Dogs: {correct_dogs}/{total_dogs}")

total_correct = correct_cats + correct_dogs
total = total_cats + total_dogs

print(f"Accuracy: {total_correct / total * 100:.2f}%")
# Out:
# ❌ قطة تم تصنيفها كلب: '''.jpg
# ❌ قطة تم تصنيفها كلب: ,,,.jpg
# ❌ قطة تم تصنيفها كلب: ....jpg
# ❌ قطة تم تصنيفها كلب: 8888.jpg
# ❌ قطة تم تصنيفها كلب: aaa.jpg
# ❌ قطة تم تصنيفها كلب: bbbb.jpg
# ❌ قطة تم تصنيفها كلب: ccc.jpg
# ❌ قطة تم تصنيفها كلب: dddd.jpg
# ❌ قطة تم تصنيفها كلب: eee.jpg
# ❌ قطة تم تصنيفها كلب: ffff.jpg
# ❌ قطة تم تصنيفها كلب: ggggg.jpg
# ❌ قطة تم تصنيفها كلب: gggggg.jpg
# ❌ قطة تم تصنيفها كلب: hhhh.jpg
# ❌ قطة تم تصنيفها كلب: iiiiii.jpg
# ❌ قطة تم تصنيفها كلب: jjjjj.jpg
# ❌ قطة تم تصنيفها كلب: kkk975.jpg
# ❌ قطة تم تصنيفها كلب: kkkk.jpg
# ❌ قطة تم تصنيفها كلب: llllll.jpg
# ❌ قطة تم تصنيفها كلب: mmm.jpg
# ❌ قطة تم تصنيفها كلب: nnnn.jpg
# ❌ قطة تم تصنيفها كلب: nnnnnn.jpg
# ❌ قطة تم تصنيفها كلب: oooo.jpg
# ❌ قطة تم تصنيفها كلب: ooooo.jpg
# ❌ قطة تم تصنيفها كلب: ppp.jpg
# ❌ قطة تم تصنيفها كلب: ppppp98.jpg
# ❌ قطة تم تصنيفها كلب: vvv.jpg
# ❌ قطة تم تصنيفها كلب: zzz.jpg
# ==================================================
# نتيجة الاختبار بنفس طريقة الواجهة
# ==================================================
# Cats: 0/27
# Dogs: 27/27
# Accuracy: 50.00%

# %%
import numpy as np
import tensorflow as tf
import gradio as gr

# تحميل النموذج
model = tf.keras.models.load_model("ultimate_cat_dog_model.keras")

# دالة التنبؤ
def predict_image(image):

    if image is None:
        return "⚠️ اختر صورة أولاً"

    # تحويل الصورة
    image = image.convert("RGB")
    image = image.resize((224, 224))

    # تحويلها إلى مصفوفة
    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    # مهم:
    # لا نستخدم preprocess_input هنا
    # لأن النموذج يحتوي على preprocessing داخله

    prediction = float(model.predict(x, verbose=0)[0][0])

    # تحديد النتيجة
    if prediction >= 0.5:
        result = "🐶 DOG"
        confidence = prediction * 100
    else:
        result = "🐱 CAT"
        confidence = (1 - prediction) * 100

    return f"{result}\nنسبة الثقة: {confidence:.2f}%"

# إنشاء الواجهة
demo = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(
        type="pil",
        label="📷 اختر صورة"
    ),
    outputs=gr.Textbox(
        label="🔍 النتيجة",
        lines=2
    ),
    title="🐱🐶 Cat vs Dog",
    description="ارفع صورة وسيحدد النموذج هل هي قطة أم كلب."
)

# تشغيل الواجهة
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
import numpy as np
import tensorflow as tf
import gradio as gr

# ==========================================
# تحميل النموذج
# ==========================================
model = tf.keras.models.load_model("ultimate_cat_dog_model.keras")


# ==========================================
# دالة التصنيف
# ==========================================
def predict_image(image):
    if image is None:
        return "⚠️ اختر صورة أولاً"

    image = image.convert("RGB")
    image = image.resize((224, 224))

    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    # لا نستخدم preprocess_input هنا
    # لأن النموذج يحتوي عليه بالفعل
    prediction = float(model.predict(x, verbose=0)[0][0])

    if prediction >= 0.5:
        result = "🐶 DOG"
        confidence = prediction * 100
    else:
        result = "🐱 CAT"
        confidence = (1 - prediction) * 100

    return (
        f"{result}\n"
        f"ثقة التنبؤ بهذه الصورة: {confidence:.2f}%"
    )


# ==========================================
# معلومات الدقة الحقيقية
# ==========================================
accuracy_text = """
### 📊 دقة النموذج الحقيقية

**Validation Accuracy:** 99.46%  
على 370 صورة

**Test Accuracy:** 100.00%  
على 54 صورة (54/54 صحيحة)

⚠️ نسبة "ثقة التنبؤ" بالصورة التي ترفعها ليست دقة النموذج.
"""


# ==========================================
# الواجهة
# ==========================================
with gr.Blocks() as demo:

    gr.Markdown("# 🐱🐶 Cat vs Dog Classifier")

    gr.Markdown(
        "ارفع صورة لمعرفة تصنيف النموذج لها."
    )

    image = gr.Image(
        type="pil",
        label="📷 اختر صورة"
    )

    output = gr.Textbox(
        label="🔍 النتيجة",
        lines=3
    )

    button = gr.Button("🔎 تصنيف الصورة")

    button.click(
        fn=predict_image,
        inputs=image,
        outputs=output
    )

    gr.Markdown(accuracy_text)

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import numpy as np
import tensorflow as tf
import gradio as gr
from PIL import Image, ImageOps

# =========================================================
# تحميل النموذج
# =========================================================
MODEL_PATH = "ultimate_cat_dog_model.keras"
model = tf.keras.models.load_model(MODEL_PATH)

IMG_SIZE = (224, 224)


# =========================================================
# تجهيز الصورة
# =========================================================
def prepare_image(img):
    img = img.convert("RGB")
    img = img.resize(IMG_SIZE)

    x = np.array(img, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    # مهم:
    # لا نستخدم preprocess_input هنا
    # لأن النموذج يحتوي عليه داخليًا.
    return x


# =========================================================
# Test-Time Augmentation
# =========================================================
def predict_tta(image):
    if image is None:
        return "⚠️ اختر صورة أولاً"

    image = image.convert("RGB")

    images = [
        image,
        ImageOps.mirror(image),
        image.rotate(5),
        image.rotate(-5),
        image.resize((240, 240)).crop((8, 8, 232, 232)),
    ]

    predictions = []

    for img in images:
        x = prepare_image(img)

        p_dog = float(
            model.predict(x, verbose=0)[0][0]
        )

        predictions.append(p_dog)

    predictions = np.array(predictions)

    # المتوسط أكثر استقرارًا من استخدام صورة واحدة
    p_dog = float(np.mean(predictions))
    p_cat = 1.0 - p_dog

    # تحديد النتيجة
    if p_dog >= 0.5:
        label = "🐶 DOG"
        confidence = p_dog * 100
    else:
        label = "🐱 CAT"
        confidence = p_cat * 100

    # درجة الثقة
    if confidence >= 95:
        level = "🔥 ثقة عالية جدًا"
    elif confidence >= 85:
        level = "✅ ثقة عالية"
    elif confidence >= 70:
        level = "🟡 ثقة جيدة"
    else:
        level = "⚠️ ثقة منخفضة"

    return (
        f"{label}\n\n"
        f"درجة الثقة: {confidence:.2f}%\n"
        f"{level}\n\n"
        f"احتمال CAT: {p_cat * 100:.2f}%\n"
        f"احتمال DOG: {p_dog * 100:.2f}%"
    )


# =========================================================
# الواجهة
# =========================================================
with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🐱🐶 Cat vs Dog
        ### ارفع صورة وسيقوم النموذج بتحليلها بعدة مرات للحصول على تنبؤ أكثر استقرارًا.
        """
    )

    image = gr.Image(
        type="pil",
        label="📷 اختر صورة"
    )

    button = gr.Button(
        "🔎 تحليل الصورة"
    )

    result = gr.Textbox(
        label="النتيجة",
        lines=7
    )

    button.click(
        fn=predict_tta,
        inputs=image,
        outputs=result
    )

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
import numpy as np
import tensorflow as tf
import gradio as gr

model = tf.keras.models.load_model("ultimate_cat_dog_model.keras")

def predict_image(image):
    if image is None:
        return "⚠️ اختر صورة أولاً"

    image = image.convert("RGB")
    image = image.resize((224, 224))

    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    prediction = float(model.predict(x, verbose=0)[0][0])

    if prediction >= 0.5:
        result = "🐶 DOG"
        confidence = prediction * 100
    else:
        result = "🐱 CAT"
        confidence = (1 - prediction) * 100

    return f"{result}\nدرجة الثقة: {confidence:.2f}%"

demo = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil", label="📷 اختر صورة"),
    outputs=gr.Textbox(label="🔍 النتيجة", lines=2),
    title="🐱🐶 Cat vs Dog"
)

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
import os
import numpy as np
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

# =========================================================
# الإعدادات
# =========================================================

DATASET_PATH = os.path.join(os.getcwd(), "dataset")
TEST_PATH = os.path.join(os.getcwd(), "test")

IMG_SIZE = (299, 299)
BATCH_SIZE = 16
SEED = 1337

# =========================================================
# تحميل البيانات
# =========================================================

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.20,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.20,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_PATH,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False
)

class_names = train_ds.class_names

print("Classes:", class_names)

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(
    1000, seed=SEED
).prefetch(AUTOTUNE)

val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

# =========================================================
# Augmentation أقوى
# =========================================================

augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.12),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomContrast(0.15),
], name="augmentation")

# =========================================================
# Xception
# =========================================================

base_model = Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(299, 299, 3)
)

base_model.trainable = False

inputs = layers.Input(
    shape=(299, 299, 3),
    name="image"
)

x = augmentation(inputs)

x = tf.keras.applications.xception.preprocess_input(x)

x = base_model(
    x,
    training=False
)

x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)

x = layers.Dropout(0.40)(x)

x = layers.Dense(
    256,
    activation="relu"
)(x)

x = layers.Dropout(0.30)(x)

outputs = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs,
    outputs
)

# =========================================================
# المرحلة الأولى
# =========================================================

print("\n" + "=" * 60)
print("المرحلة الأولى")
print("=" * 60)

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=1e-3
    ),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

checkpoint1 = ModelCheckpoint(
    "strong_stage1.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early1 = EarlyStopping(
    monitor="val_loss",
    patience=6,
    restore_best_weights=True,
    verbose=1
)

reduce1 = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[
        checkpoint1,
        early1,
        reduce1
    ]
)

# =========================================================
# المرحلة الثانية Fine-Tuning
# =========================================================

print("\n" + "=" * 60)
print("المرحلة الثانية - Fine Tuning")
print("=" * 60)

base_model.trainable = True

# فتح آخر 80 طبقة
for layer in base_model.layers[:-80]:
    layer.trainable = False

# إبقاء BatchNormalization مجمدة
for layer in base_model.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=5e-6
    ),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

checkpoint2 = ModelCheckpoint(
    "strong_cat_dog_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early2 = EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True,
    verbose=1
)

reduce2 = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-8,
    verbose=1
)

model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[
        checkpoint2,
        early2,
        reduce2
    ]
)

# =========================================================
# تحميل أفضل نموذج
# =========================================================

model = tf.keras.models.load_model(
    "strong_cat_dog_model.keras"
)

# =========================================================
# اختبار Test
# =========================================================

print("\n" + "=" * 60)
print("TEST")
print("=" * 60)

results = model.evaluate(
    test_ds,
    verbose=1
)

for name, value in zip(
    model.metrics_names,
    results
):
    print(f"{name}: {value:.4f}")

# =========================================================
# حفظ النموذج النهائي
# =========================================================

model.save(
    "ultimate_strong_cat_dog_model.keras"
)

print("\nتم الحفظ:")
print("ultimate_strong_cat_dog_model.keras")
# Out:
# Found 1852 files belonging to 2 classes.
# Using 1482 files for training.
# Found 1852 files belonging to 2 classes.
# Using 370 files for validation.
# Found 54 files belonging to 2 classes.
# Classes: ['cats', 'dogs']
#
# ============================================================
# المرحلة الأولى
# ============================================================
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# 93/93 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9575 - precision: 0.9584 - recall: 0.9572
# Epoch 1: val_accuracy improved from -inf to 0.98378, saving model to strong_stage1.keras
# 93/93 [==============================] - 59s 509ms/step - loss: 0.1388 - accuracy: 0.9575 - precision: 0.9584 - recall: 0.9572 - val_loss: 0.1285 - val_accuracy: 0.9838 - val_precision: 1.0000 - val_recall: 0.9838 - lr: 0.0010
# Epoch 2/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9757 - precision: 0.9759 - recall: 0.9759
# Epoch 2: val_accuracy improved from 0.98378 to 0.99730, saving model to strong_stage1.keras
# 93/93 [==============================] - 46s 496ms/step - loss: 0.0967 - accuracy: 0.9757 - precision: 0.9759 - recall: 0.9759 - val_loss: 0.0235 - val_accuracy: 0.9973 - val_precision: 1.0000 - val_recall: 0.9973 - lr: 0.0010
# Epoch 3/20
# 93/93 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.
- accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# loss: 0.0018
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
#
# تم الحفظ:
# ultimate_strong_cat_dog_model.keras

# %%
import numpy as np
import tensorflow as tf
from PIL import Image

model = tf.keras.models.load_model(
    "ultimate_strong_cat_dog_model.keras"
)

image_path = r"D:\Ai 3\ddd\Dr.2\Dr.1\test\cat.jpeg"

image = Image.open(image_path).convert("RGB")
image = image.resize((299, 299))

x = np.array(image, dtype=np.float32)
x = np.expand_dims(x, axis=0)

prediction = float(
    model.predict(x, verbose=0)[0][0]
)

p_dog = prediction * 100
p_cat = (1 - prediction) * 100

if prediction >= 0.5:
    print(f"🐶 DOG")
    print(f"درجة الثقة: {p_dog:.2f}%")
else:
    print(f"🐱 CAT")
    print(f"درجة الثقة: {p_cat:.2f}%")

print(f"\nCAT: {p_cat:.2f}%")
print(f"DOG: {p_dog:.2f}%")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# 🐱 CAT
# درجة الثقة: 95.39%
#
# CAT: 95.39%
# DOG: 4.61%

# %%
import numpy as np
import tensorflow as tf
import gradio as gr

# ==========================================
# تحميل النموذج الأقوى
# ==========================================
MODEL_PATH = "ultimate_strong_cat_dog_model.keras"

model = tf.keras.models.load_model(MODEL_PATH)

IMG_SIZE = (299, 299)


# ==========================================
# دالة التصنيف
# ==========================================
def predict_image(image):

    if image is None:
        return "⚠️ اختر صورة أولاً"

    # تحويل الصورة
    image = image.convert("RGB")
    image = image.resize(IMG_SIZE)

    # تحويل إلى مصفوفة
    x = np.array(image, dtype=np.float32)
    x = np.expand_dims(x, axis=0)

    # مهم:
    # لا نستخدم preprocess_input هنا
    # لأنه موجود داخل النموذج

    prediction = float(
        model.predict(x, verbose=0)[0][0]
    )

    p_dog = prediction * 100
    p_cat = (1 - prediction) * 100

    if prediction >= 0.5:
        result = "🐶 DOG"
        confidence = p_dog
    else:
        result = "🐱 CAT"
        confidence = p_cat

    return (
        f"{result}\n\n"
        f"درجة الثقة: {confidence:.2f}%\n\n"
        f"🐱 CAT: {p_cat:.2f}%\n"
        f"🐶 DOG: {p_dog:.2f}%"
    )


# ==========================================
# إنشاء الواجهة
# ==========================================
with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🐱🐶 Cat vs Dog Classifier
        ### النموذج المحسن — Xception 299×299
        """
    )

    image = gr.Image(
        type="pil",
        label="📷 اختر صورة قط أو كلب"
    )

    button = gr.Button(
        "🔎 تحليل الصورة"
    )

    result = gr.Textbox(
        label="النتيجة",
        lines=6
    )

    button.click(
        fn=predict_image,
        inputs=image,
        outputs=result
    )

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------

# %%
import sys
import tensorflow as tf
import numpy as np
import PIL
import sklearn
import gradio

print("Python       :", sys.version.split()[0])
print("TensorFlow   :", tf.__version__)
print("NumPy        :", np.__version__)
print("Pillow       :", PIL.__version__)
print("Scikit-learn :", sklearn.__version__)
print("Gradio       :", gradio.__version__)
# Out:
# Python       : 3.9.25
# TensorFlow   : 2.10.0
# NumPy        : 1.26.4
# Pillow       : 10.4.0
# Scikit-learn : 1.6.1
# Gradio       : 3.50.2
